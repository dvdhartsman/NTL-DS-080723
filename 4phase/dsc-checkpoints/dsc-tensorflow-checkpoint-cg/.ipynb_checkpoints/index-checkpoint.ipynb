# %% [markdown]
# # TensorFlow Checkpoint
#
# This assessment covers building and training a `tf.keras` `Sequential` model, then applying regularization.  The dataset comes from a ["don't overfit" Kaggle competition](https://www.kaggle.com/c/dont-overfit-ii).  There are 300 features labeled 0-299, and a binary target called "target".  There are only 250 records total, meaning this is a very small dataset to be used with a neural network.
#
# _You can assume that the dataset has already been scaled._

# %%
# Run this cell without changes

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Sequential, regularizers
# from tensorflow.keras.regularizers import l2 specifically from the regularization lab

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# Out:
# 2023-10-18 15:46:19.440458: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 1) Prepare Data for Modeling
#
# * Using `pandas`, open the file `data.csv` as a DataFrame
# * Drop the `"id"` column, since this is a unique identifier and not a feature
# * Separate the data into `X` (a DataFrame with all columns except `"target"`) and `y` (a Series with just the `"target"` column)
# * The train-test split should work as-is once you create these variables

# %%
# CodeGrade step1
# Replace None with appropriate code

# Read in the data
df = pd.read_csv('data.csv')

# Drop the "id" column
df.drop(columns='id', inplace = True)

# Separate into X and y
X = df.drop(columns="target")
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2021)

# %%
assert type(df) == pd.DataFrame
assert type(X) == pd.DataFrame
assert type(y) == pd.Series

# %% [markdown]
# ## 2) Instantiate a `Sequential` Model
#
# In the cell below, create an instance of a `Sequential` model ([documentation here](https://keras.io/guides/sequential_model/)) called `dense_model` with a `name` of `"dense"` and otherwise default arguments.
#
# *In other words, create a model without any layers. We will add layers in a future step.*

# %%
# CodeGrade step2
# Replace None with appropriate code
dense_model = Sequential(name="dense")

dense_model.name
# Out:
# 'dense'

# %%
# Model should not have any layers yet
assert len(dense_model.layers) == 0

# %% [markdown]
# ## 3) Determine Input and Output Shapes
#
# How many input and output nodes should this model have?
#
# Feel free to explore the attributes of `X` and `y` to determine this answer, or just to enter numbers based on the problem description above.

# %%
y_train.value_counts(), X_train.shape
# Out:
# (target
#  0.0    135
#  1.0     52
#  Name: count, dtype: int64,
#  (187, 300))

# %%
# CodeGrade step3
# Replace None with appropriate code
num_input_nodes = 300  # 300 columns
num_output_nodes = 1  # because it is a binary classification

# %%
# Both values should be integers
assert type(num_input_nodes) == int
assert type(num_output_nodes) == int

# %% [markdown]
# The code below will use the input and output shapes you specified to add `Dense` layers to the model:

# %%
# Run this cell without changes

# Add input layer
dense_model.add(Dense(units=64, input_shape=(num_input_nodes,)))

# Add hidden layers
dense_model.add(Dense(units=64))
dense_model.add(Dense(units=64))

dense_model.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x7fd6cffae7f0>,
#  <keras.layers.core.dense.Dense at 0x7fd6ce6f3fd0>,
#  <keras.layers.core.dense.Dense at 0x7fd6cfeaaee0>]

# %% [markdown]
# ## 4) Add an Output Layer
#
# Specify an appropriate activation function ([documentation here](https://keras.io/api/layers/activations/)).
#
# We'll simplify the problem by specifying that you should use the string identifier for the function, and it should be one of these options:
#
# * `sigmoid`
# * `softmax`
#
# ***Hint:*** is this a binary or a multi-class problem? This should guide your choice of activation function.

# %%
# CodeGrade step4
# Replace None with appropriate code
activation_function = 'sigmoid'

# %%
# activation_function should be a string
assert type(activation_function) == str

# %% [markdown]
# Now we'll use that information to finalize the model.
#
# If this code produces an error, consider restarting the kernel and re-running the code above. If it still produces an error, that is an indication that one or more of your answers above is incorrect.

# %%
# Run this cell without changes

# Add output layer
dense_model.add(Dense(units=num_output_nodes, activation=activation_function))

# Determine appropriate loss function
if num_output_nodes == 1:
    loss = "binary_crossentropy"
else:
    loss = "categorical_crossentropy"

# Compile model
dense_model.compile(
    optimizer="adam",
    loss=loss,
    metrics=["accuracy"]
)

dense_model.summary()
# Out:
# Model: "dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                19264
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 27,649
# Trainable params: 27,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Run this cell without changes

# Fit the model to the training data, using a subset of the
# training data as validation data
dense_model_results = dense_model.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=1,
    validation_split=0.4,
    shuffle=False
)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 1s 80ms/step - loss: 0.8660 - accuracy: 0.5625 - val_loss: 1.2559 - val_accuracy: 0.5200
# Epoch 2/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3878 - accuracy: 0.8125 - val_loss: 1.2085 - val_accuracy: 0.4933
# Epoch 3/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2342 - accuracy: 0.9375 - val_loss: 1.2430 - val_accuracy: 0.4667
# Epoch 4/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1468 - accuracy: 0.9911 - val_loss: 1.3296 - val_accuracy: 0.4400
# Epoch 5/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0885 - accuracy: 1.0000 - val_loss: 1.4435 - val_accuracy: 0.4667
# Epoch 6/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 1.5648 - val_accuracy: 0.4667
# Epoch 7/20
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 1.6822 - val_accuracy: 0.4533
# Epoch 8/20
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.7900 - val_accuracy: 0.4933
# Epoch 9/20
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.8850 - val_accuracy: 0.5200
# Epoch 10/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.9663 - val_accuracy: 0.5200
# Epoch 11/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.0345 - val_accuracy: 0.5200
# Epoch 12/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.0909 - val_accuracy: 0.5333
# Epoch 13/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.1376 - val_accuracy: 0.5333
# Epoch 14/20
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.1763 - val_accuracy: 0.5333
# Epoch 15/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.2088 - val_accuracy: 0.5333
# Epoch 16/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.2365 - val_accuracy: 0.5333
# Epoch 17/20
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.2605 - val_accuracy: 0.5333
# Epoch 18/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.2816 - val_accuracy: 0.5467
# Epoch 19/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.3005 - val_accuracy: 0.5467
# Epoch 20/20
# 4/4 [==============================] - 0s 28ms/step - loss: 9.6723e-04 - accuracy: 1.0000 - val_loss: 2.3177 - val_accuracy: 0.5467

# %%
# Run this cell without changes

def plot_loss_and_accuracy(results, final=False):
    
    if final:
        val_label="test"
    else:
        val_label="validation"

    # Extracting metrics from model fitting
    train_loss = results.history['loss']
    val_loss = results.history['val_loss']
    train_accuracy = results.history['accuracy']
    val_accuracy = results.history['val_accuracy']

    # Setting up plots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    # Plotting loss info
    ax1.set_title("Loss")
    sns.lineplot(x=results.epoch, y=train_loss, ax=ax1, label="train")
    sns.lineplot(x=results.epoch, y=val_loss, ax=ax1, label=val_label)
    ax1.legend()

    # Plotting accuracy info
    ax2.set_title("Accuracy")
    sns.lineplot(x=results.epoch, y=train_accuracy, ax=ax2, label="train")
    sns.lineplot(x=results.epoch, y=val_accuracy, ax=ax2, label=val_label)
    ax2.legend()
    
plot_loss_and_accuracy(dense_model_results)

# %% [markdown]
# ## 5) Modify the Code Below to Use Regularization
#
#
# The model appears to be overfitting. To deal with this overfitting, modify the code below to include regularization in the model. You can add L1, L2, both L1 and L2, or dropout regularization.
#
# Hint: these might be helpful
#
#  - [`Dense` layer documentation](https://keras.io/api/layers/core_layers/dense/)
#  - [`regularizers` documentation](https://keras.io/regularizers/)
#
# (`EarlyStopping` is a type of regularization that is not applicable to this problem framing, since it's a callback and not a layer.)

# %% [markdown]
# ### This import statement needed to be run in order to use l2 regularization

# %%
from tensorflow.keras.regularizers import l2

# %%
# CodeGrade step5

def build_model_with_regularization(n_input, n_output, activation, loss):
    """
    Creates and compiles a tf.keras Sequential model with two hidden layers
    This time regularization has been added
    """
    # create classifier
    classifier = Sequential(name="regularized")

    # add input layer
    classifier.add(Dense(units=64, input_shape=(n_input,)))

    # add hidden layers
    classifier.add(Dense(units=64))
    
    classifier.add(Dense(20, activation='relu',
                kernel_regularizer=l2(l2=0.1)))

    
    classifier.add(Dropout(.5))
        
    classifier.add(Dense(32))
    
    classifier.add(Dropout(.5))
    
    classifier.add(Dense(16))
    
    classifier.add(Dropout(.5))
    
    classifier.add(Dense(8))

    # add output layer
    classifier.add(Dense(units=n_output, activation=activation))

    classifier.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return classifier

model_with_regularization = build_model_with_regularization(
    num_input_nodes, num_output_nodes, activation_function, loss
)
model_with_regularization.summary()
# Out:
# Model: "regularized"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_78 (Dense)            (None, 64)                19264
#
#  dense_79 (Dense)            (None, 64)                4160
#
#  dense_80 (Dense)            (None, 20)                1300
#
#  dropout_25 (Dropout)        (None, 20)                0
#
#  dense_81 (Dense)            (None, 32)                672
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_82 (Dense)            (None, 16)                528
#
#  dropout_27 (Dropout)        (None, 16)                0
#
#  dense_83 (Dense)            (None, 8)                 136
#
#  dense_84 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 26,069
# Trainable params: 26,069
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Testing function to build model
assert type(model_with_regularization) == Sequential

# %% [markdown]
# Now we'll evaluate the new model on the training set as well:

# %%
# Run this cell without changes

# Fit the model to the training data, using a subset of the
# training data as validation data
reg_model_results = model_with_regularization.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=0,
    validation_split=0.4,
    shuffle=False
)

plot_loss_and_accuracy(reg_model_results)

# %% [markdown]
# (Whether or not your regularization made a difference will partially depend on how strong of regularization you applied, as well as some random elements of your current TensorFlow configuration.)
#
# Now we evaluate both models on the holdout set:

# %%
# Run this cell without changes

final_dense_model_results = dense_model.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=0,
    validation_data=(X_test, y_test),
    shuffle=False
)

plot_loss_and_accuracy(final_dense_model_results, final=True)

# %%
# Run this cell without changes

final_reg_model_results = model_with_regularization.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=0,
    validation_data=(X_test, y_test),
    shuffle=False
)

plot_loss_and_accuracy(final_reg_model_results, final=True)

# %%
# The model with regularization performed better, however there was still a significant amount of overfitting
